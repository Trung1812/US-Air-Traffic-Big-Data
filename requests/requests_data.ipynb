# %%
import requests

# %%
# !ls
# Out:
# requests_data.ipynb

# %%
import requests
import json
import sys


API_KEY = "7a261a4fd48779425e4a75783f089b68"
BASE_URL = "http://api.aviationstack.com/v1/flights"

# Define parameters
params = {
    "access_key": API_KEY,
    #"dep_iata": "LHR",  # Filter flights departing from London Heathrow
    # OR
    # "arr_iata": "LGW",  # Filter flights arriving at London Gatwick
    "dep_country": "United Kingdom",  # Filter by country
}

# Make the request
response = requests.get(BASE_URL, params=params)

# Parse and print the response
if response.status_code == 200:
    data = response.json()

    with open('/Users/phamquangtrung/Desktop/Big-Data-UK-Airline-Data-Analysis/data/test.json', 'w') as file:
        json.dump(data, file)
    print(data)
else:
    print(f"Error: {response.status_code}, {response.text}")
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 384251}, 'data': [{'flight_date': '2024-11-22', 'flight_status': 'scheduled', 'departure': {'airport': 'Dubbo', 'timezone': 'Australia/Sydney', 'iata': 'DBO', 'icao': 'YSDU', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-11-22T08:45:00+00:00', 'estimated': '2024-11-22T08:45:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Parkes', 'timezone': 'Australia/Sydney', 'iata': 'PKE', 'icao': 'YPKS', 'terminal': '2', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-11-20T09:26:00+00:00', 'estimated': '2024-11-20T09:26:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'empty', 'iata': None, 'icao': None}, 'flight': {'number': None, 'iata': None, 'icao': None, 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-11-21', 'flight_status': 'landed', 'departure': {'airport': 'Lizard Island', 'timezone': 'Australia/Brisbane', 'iata': 'LZR', 'icao': 'YLZI', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-11-21T12:25:00+00:00', 'estimated': '2024-11-21T12:25:00+00:00', 'actual': '2024-11-20T14:15:00+00:00', 'estimated_runway': '2024-11-20T14:15:00+00:00', 'actual_runway': '2024-11-20T14:15:00+00:00'}, 'arrival': {'airport': 'Cairns', 'timezone': 'Australia/Brisbane', 'iata': 'CNS', 'icao': 'YBCS', 'terminal': '2', 'gate': None, 'baggage': None, 'delay': 4, 'scheduled': '2024-11-20T14:50:00+00:00', 'estimated': '2024-11-20T14:50:00+00:00', 'actual': '2024-11-20T14:54:00+00:00', 'estimated_runway': '2024-11-20T14:54:00+00:00', 'actual_runway': '2024-11-20T14:54:00+00:00'}, 'airline': {'name': 'Hinterland Aviation', 'iata': 'OI', 'icao': 'HND'}, 'flight': {'number': '455', 'iata': 'OI455', 'icao': 'HND455', 'codeshared': None}, 'aircraft': {'registration': 'VH-HLJ', 'iata': 'BE20', 'icao': 'BE20', 'icao24': '7C2505'}, 'live': None}, {'flight_date': '2024-11-21', 'flight_status': 'scheduled', 'departure': {'airport': 'Auckland International', 'timezone': 'Pacific/Auckland', 'iata': 'AKL', 'icao': 'NZAA', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-11-21T03:25:00+00:00', 'estimated': '2024-11-21T03:25:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Hong Kong International', 'timezone': 'Asia/Hong_Kong', 'iata': 'HKG', 'icao': 'VHHH', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-11-21T10:00:00+00:00', 'estimated': '2024-11-21T10:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Emirates', 'iata': 'EK', 'icao': 'UAE'}, 'flight': {'number': '9824', 'iata': 'EK9824', 'icao': 'UAE9824', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-11-21', 'flight_status': 'scheduled', 'departure': {'airport': 'Launceston', 'timezone': 'Australia/Hobart', 'iata': 'LST', 'icao': 'YMLT', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-11-21T02:10:00+00:00', 'estimated': '2024-11-21T02:10:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Melbourne - Tullamarine Airport', 'timezone': 'Australia/Melbourne', 'iata': 'MEL', 'icao': 'YMML', 'terminal': '3', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-11-21T02:59:00+00:00', 'estimated': '2024-11-21T02:59:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Texel Air', 'iata': None, 'icao': 'XLR'}, 'flight': {'number': '94', 'iata': None, 'icao': 'XLR94', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-11-21', 'flight_status': 'scheduled', 'departure': {'airport': 'Seoul (Incheon)', 'timezone': 'Asia/Seoul', 'iata': 'ICN', 'icao': 'RKSI', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-11-21T00:05:00+00:00', 'estimated': '20 ...

# %%
import requests
import json
import sys


API_KEY = "7a261a4fd48779425e4a75783f089b68"
BASE_URL = "http://api.aviationstack.com/v1/flights"

# Define parameters
params = {
    "access_key": API_KEY,
    #"dep_iata": "LHR",  # Filter flights departing from London Heathrow
    # OR
    # "arr_iata": "LGW",  # Filter flights arriving at London Gatwick
    "dep_country": "United Kingdom",  # Filter by country
    "flight_status": 'landed',
}

# Make the request
response = requests.get(BASE_URL, params=params)

# Parse and print the response
if response.status_code == 200:
    data = response.json()

    with open('/Users/phamquangtrung/Desktop/Big-Data-UK-Airline-Data-Analysis/data/test2.json', 'w') as file:
        json.dump(data, file)
    print(data)
else:
    print(f"Error: {response.status_code}, {response.text}")
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 229031}, 'data': [{'flight_date': '2024-11-21', 'flight_status': 'landed', 'departure': {'airport': 'Changsha', 'timezone': 'Asia/Shanghai', 'iata': 'CSX', 'icao': 'ZGHA', 'terminal': '1', 'gate': '1-7', 'delay': 22, 'scheduled': '2024-11-21T10:25:00+00:00', 'estimated': '2024-11-21T10:25:00+00:00', 'actual': '2024-11-21T10:47:00+00:00', 'estimated_runway': '2024-11-21T10:47:00+00:00', 'actual_runway': '2024-11-21T10:47:00+00:00'}, 'arrival': {'airport': 'Shuangliu', 'timezone': 'Asia/Shanghai', 'iata': 'CTU', 'icao': 'ZUUU', 'terminal': '2', 'gate': None, 'baggage': '12', 'delay': 5, 'scheduled': '2024-11-21T12:20:00+00:00', 'estimated': '2024-11-21T12:20:00+00:00', 'actual': '2024-11-21T12:25:00+00:00', 'estimated_runway': '2024-11-21T12:25:00+00:00', 'actual_runway': '2024-11-21T12:25:00+00:00'}, 'airline': {'name': 'Juneyao Airlines', 'iata': 'HO', 'icao': 'DKH'}, 'flight': {'number': '5899', 'iata': 'HO5899', 'icao': 'DKH5899', 'codeshared': {'airline_name': 'sichuan airlines', 'airline_iata': '3u', 'airline_icao': 'csc', 'flight_number': '8766', 'flight_iata': '3u8766', 'flight_icao': 'csc8766'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-11-21', 'flight_status': 'landed', 'departure': {'airport': 'Changsha', 'timezone': 'Asia/Shanghai', 'iata': 'CSX', 'icao': 'ZGHA', 'terminal': '1', 'gate': '1-7', 'delay': 22, 'scheduled': '2024-11-21T10:25:00+00:00', 'estimated': '2024-11-21T10:25:00+00:00', 'actual': '2024-11-21T10:47:00+00:00', 'estimated_runway': '2024-11-21T10:47:00+00:00', 'actual_runway': '2024-11-21T10:47:00+00:00'}, 'arrival': {'airport': 'Shuangliu', 'timezone': 'Asia/Shanghai', 'iata': 'CTU', 'icao': 'ZUUU', 'terminal': '2', 'gate': None, 'baggage': '12', 'delay': 5, 'scheduled': '2024-11-21T12:20:00+00:00', 'estimated': '2024-11-21T12:20:00+00:00', 'actual': '2024-11-21T12:25:00+00:00', 'estimated_runway': '2024-11-21T12:25:00+00:00', 'actual_runway': '2024-11-21T12:25:00+00:00'}, 'airline': {'name': 'Xiamen Airlines', 'iata': 'MF', 'icao': 'CXA'}, 'flight': {'number': '5562', 'iata': 'MF5562', 'icao': 'CXA5562', 'codeshared': {'airline_name': 'sichuan airlines', 'airline_iata': '3u', 'airline_icao': 'csc', 'flight_number': '8766', 'flight_iata': '3u8766', 'flight_icao': 'csc8766'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-11-21', 'flight_status': 'landed', 'departure': {'airport': 'Changsha', 'timezone': 'Asia/Shanghai', 'iata': 'CSX', 'icao': 'ZGHA', 'terminal': '1', 'gate': '1-7', 'delay': 22, 'scheduled': '2024-11-21T10:25:00+00:00', 'estimated': '2024-11-21T10:25:00+00:00', 'actual': '2024-11-21T10:47:00+00:00', 'estimated_runway': '2024-11-21T10:47:00+00:00', 'actual_runway': '2024-11-21T10:47:00+00:00'}, 'arrival': {'airport': 'Shuangliu', 'timezone': 'Asia/Shanghai', 'iata': 'CTU', 'icao': 'ZUUU', 'terminal': '2', 'gate': None, 'baggage': '12', 'delay': 5, 'scheduled': '2024-11-21T12:20:00+00:00', 'estimated': '2024-11-21T12:20:00+00:00', 'actual': '2024-11-21T12:25:00+00:00', 'estimated_runway': '2024-11-21T12:25:00+00:00', 'actual_runway': '2024-11-21T12:25:00+00:00'}, 'airline': {'name': 'Chengdu Airlines', 'iata': 'EU', 'icao': 'UEA'}, 'flight': {'number': '7301', 'iata': 'EU7301', 'icao': 'UEA7301', 'codeshared': {'airline_name': 'sichuan airlines', 'airline_iata': '3u', 'airline_icao': 'csc', 'flight_number': '8766', 'flight_iata': '3u8766', 'flight_icao': 'csc8766'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-11-21', 'flight_status': 'landed', 'departure': {'airport': 'Changsha', 'timezone': 'Asia/Shanghai', 'iata': 'CSX', 'icao': 'ZGHA', 'terminal': '1', 'gate': '1-7', 'delay': 22, 'scheduled': '2024-11-21T10:25:00+00:00', 'estimated': '2024-11-21T10:25:00+00:00', 'actual': '2024-11-21T10:47:00+00:00', 'estimated_runway': '2024-11-21T10:47:00+00:00', 'actual_runway': '2024-11-21T10:47:00+00:00'}, 'arrival': {'airport': 'Shuangliu', 'timezone': 'Asia/Shanghai', 'iata': 'CTU', 'icao': 'ZU ...
